# %%
import pandas as pd
import sys

sys.path.insert(1, '../')

from rule_benchmark import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
FOLDERS = ["approach1", "approach2"]

# %%
train = pd.read_pickle("train.pkl")
test = pd.read_pickle("test.pkl")

# %%
# The K parameter selects how many defuzzified predictions are used in order of decreasing confidence

fiss, algo_ranking = benchmark_rules("approach1/", train, test, K=1, n=600)
fiss, algo_ranking = benchmark_rules("approach2/", train, test, K=1, n=600)
# Out:
# Number of rules:  42
# Number of input variables:  5
# Number of output variables:  3
#
# approach1/:
#
# Container_DataLayout:
#   0%|          | 0/2172 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:105, in FuzzySet.__call__(self, data)
#     103         raise ValueError(f"Variable {name} not found in data")
# --> 105     return self.function(data[name])
#     106 except:
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:380, in Gaussian.__init__.<locals>.function(x)
# --> 380 def function(x): return np.exp(-0.5 * ((x - mean) / sigma) ** 2)
#
# ZeroDivisionError: float division by zero
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # The K parameter selects how many defuzzified predictions are used in order of decreasing confidence
# ----> 3 fiss, algo_ranking = benchmark_rules("approach1/", train, test, K=1, n=600)
#       4 fiss, algo_ranking = benchmark_rules("approach2/", train, test, K=1, n=600)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/cluster-examples-pause-rules-without-exploding-liquid/../rule_benchmark.py:309, in benchmark_rules(folder, train, test, K, n, suitability, method)
#     304 fiss, algo_ranking = createFuzzySystem(
#     305     inputVariableString, outputVariableString, rulesString)
#     307 print(f"\n{folder}:")
# --> 309 plot_accuracy(train, test, folder, fiss,
#     310               algo_ranking, K, n, suitability, method)
#     312 return fiss, algo_ranking
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/cluster-examples-pause-rules-without-exploding-liquid/../rule_benchmark.py:245, in plot_accuracy(train, test, folder, fuzzy_systems, algo_rankings, K, n, suitability, method)
#     242 for label, fisys in fuzzy_systems.items():
#     243     print(f"\n{label}:")
# --> 245     pctTrain, pctTest = calc_accuracy(train, test,
#     246                                       fisys, algo_rankings, K, n, suitability, method)
#     248     print(f"Train: {pctTrain}")
#     249     print(f"Test: {pctTest}")
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/cluster-examples-pause-rules-without-exploding-liquid/../rule_benchmark.py:210, in calc_accuracy(train, test, fisys, algo_rankings, K, n, suitability, method)
#     208 else:
#     209     for row in tqdm(train.iterrows(), total=len(train)):
# --> 210         vals, preds = fisys.predictClosest(
#     211             row[1], algo_rankings[output_variable], n=n, method=method)
#     213         true = row[1][output_variable]
#     215         for pred in preds:
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:697, in FuzzySystem.predictClosest(self, data, algo_ranking, n, method)
#     696 def predictClosest(self, data: dict, algo_ranking: dict[str, float], n=100, method="mom"):
# --> 697     cx = self.predict(data, n=n, method=method)
#     699     closest = min(algo_ranking, key=lambda x: abs(algo_ranking[x] - cx))
#     701     return cx, closest
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:692, in FuzzySystem.predict(self, data, n, method)
#     684 def predict(self, data: dict, n=100, method="mom"):
#     685     """
#     686     Apply the rules to the data and return the center of gravity of the union of the consequents.
#     687     This is also the prediction of the fuzzy system for given data
#     688
#     689     data: The input data to predict on.
#     690     """
# --> 692     union = self.applyRules(data)
#     693     (meanX, y) = union.defuzzyfy(method, n=n)
#     694     return meanX
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:672, in FuzzySystem.applyRules(self, data)
#     667 def applyRules(self, data: dict):
#     668     """
#     669     Apply all the rules to the data and return the union of the consequents.
#     670     """
# --> 672     cut_cut_consequents = [rule.apply(data) for rule in self.rules]
#     674     union = functools.reduce(lambda x, y: x | y, cut_cut_consequents)
#     676     all_based_on = []
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:628, in FuzzyRule.apply(self, data)
#     621 def apply(self, data: dict) -> FuzzySet:
#     622     """
#     623     Apply the fuzzy rule to the data.
#     624     Calculates the cut of the antecedent and returns the consequent with the cut applied.
#     625
#     626     data: The input data to apply the rule to.
#     627     """
# --> 628     cut = self.antecedent(data)
#     630     linguistic_term = f"({str(self.consequent)})↑{cut:.2f}"
#     631     crisp_set = self.consequent.crisp_set
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:111, in FuzzySet.__call__(self, data)
#     107         return self.function(data)
#     108 else:
#     109     # Function is a function a lambda function combining other fuzzy sets
#     110     # Pass the data down recursively
# --> 111     return self.function(data)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:214, in FuzzySet.__and__.<locals>.<lambda>(data)
#     212 new_linguistic_term = f"({str(self)} and {str(other)})"
#     213 new_crisp_set = self.crisp_set * other.crisp_set
# --> 214 return FuzzySet(new_linguistic_term, lambda data: min(self(data), other(data)), [self, other], crisp_set=new_crisp_set)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:111, in FuzzySet.__call__(self, data)
#     107         return self.function(data)
#     108 else:
#     109     # Function is a function a lambda function combining other fuzzy sets
#     110     # Pass the data down recursively
# --> 111     return self.function(data)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:214, in FuzzySet.__and__.<locals>.<lambda>(data)
#     212 new_linguistic_term = f"({str(self)} and {str(other)})"
#     213 new_crisp_set = self.crisp_set * other.crisp_set
# --> 214 return FuzzySet(new_linguistic_term, lambda data: min(self(data), other(data)), [self, other], crisp_set=new_crisp_set)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:111, in FuzzySet.__call__(self, data)
#     107         return self.function(data)
#     108 else:
#     109     # Function is a function a lambda function combining other fuzzy sets
#     110     # Pass the data down recursively
# --> 111     return self.function(data)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:230, in FuzzySet.__invert__.<locals>.<lambda>(data)
#     228 new_linguistic_term = f"not {str(self)}"
#     229 new_crisp_set = self.crisp_set
# --> 230 return FuzzySet(new_linguistic_term, lambda data: 1 - self(data), [self], crisp_set=new_crisp_set)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:107, in FuzzySet.__call__(self, data)
#     105         return self.function(data[name])
#     106     except:
# --> 107         return self.function(data)
#     108 else:
#     109     # Function is a function a lambda function combining other fuzzy sets
#     110     # Pass the data down recursively
#     111     return self.function(data)
#
# File ~/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:380, in Gaussian.__init__.<locals>.function(x)
# --> 380 def function(x): return np.exp(-0.5 * ((x - mean) / sigma) ** 2)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %% [markdown]
# # Findings
#
# - MoM works way better than the other methods.
# - This is probably since the output variable is categorical and therefore interpolating between them is not a good idea.
#   - Also the placement on the x-axis is somehow arbitrary. This also makes interpolation meaningless
# - Traversal is very hard to predict. Maybe because there are so many possible values.

# %%
data = {"maxDensity": 0.2, "maxParticlesPerCell": 5,  "homogeneity": 0.5,
        "particlesPerCellStdDev": 1, "avgParticlesPerCell": 1.2, "threadCount": 10}


union = fiss["Traversal"].applyRules(data)

fig, ax = plt.subplots()
union.plot(ax=ax, n=1000)

print("Union: ", union)

prediction = fiss["Traversal"].predictClosest(
    data, algo_ranking["Traversal"], n=600)[1]

print("Prediction: ", prediction)
# Out:
# Union:  "("("("("("("("("("("("("("("(Traversal is "vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(9.166666666666668, 0.07575757575757576))↑0.04" or "(Traversal is "lc_c04, lc_c08, lc_c18, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(2.5, 0.07575757575757576))↑0.41")" or "(Traversal is "vcl_c06, vcl_cluster_iteration, vlc_c18, vlc_sliced_c02": Gaussian(7.5, 0.07575757575757576))↑0.03")" or "(Traversal is "lc_c01, lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vl_list_iteration, vlc_c01, vlc_c18, vlc_sliced_c02": Gaussian(0.8333333333333334, 0.07575757575757576))↑0.03")" or "(Traversal is "lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(5.0, 0.07575757575757576))↑0.59")" or "(Traversal is "lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vl_list_iteration, vlc_c01, vlc_c18, vlc_sliced_c02": Gaussian(3.3333333333333335, 0.07575757575757576))↑0.19")" or "(Traversal is "lc_c04, lc_c04_HCP, lc_c08, lc_c18, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vcl_sliced, vcl_sliced_balanced, vcl_sliced_c02, vlc_c18, vlc_sliced, vlc_sliced_balanced, vlc_sliced_c02": Gaussian(1.6666666666666667, 0.07575757575757576))↑0.00")" or "(Traversal is "vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(9.166666666666668, 0.07575757575757576))↑0.00")" or "(Traversal is "lc_c04, lc_c08, lc_c18, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(2.5, 0.07575757575757576))↑0.41")" or "(Traversal is "lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(5.833333333333334, 0.07575757575757576))↑0.00")" or "(Traversal is "vcl_c06, vcl_cluster_iteration, vlc_c18, vlc_sliced_c02": Gaussian(7.5, 0.07575757575757576))↑0.00")" or "(Traversal is "lc_c01, lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vl_list_iteration, vlc_c01, vlc_c18, vlc_sliced_c02": Gaussian(0.8333333333333334, 0.07575757575757576))↑0.03")" or "(Traversal is "lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02": Gaussian(5.0, 0.07575757575757576))↑0.59")" or "(Traversal is "lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vl_list_iteration, vlc_c01, vlc_c18, vlc_sliced_c02": Gaussian(3.3333333333333335, 0.07575757575757576))↑0.19")" or "(Traversal is "vcl_c06, vlc_c01, vlc_c18, vlc_sliced_c02": Gaussian(8.333333333333334, 0.07575757575757576))↑0.00")"
# Prediction:  lc_c04, lc_c08, lc_sliced, lc_sliced_balanced, lc_sliced_c02, vcl_c06, vlc_c18, vlc_sliced_c02
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
