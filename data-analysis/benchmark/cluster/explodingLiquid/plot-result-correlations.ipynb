# %%
import sys
import os
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns


# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %% [markdown]
# # Load Data from Folders

# %%
from io import StringIO


data: dict[str, dict[str, dict[str, pd.DataFrame]]] = {}

directories = []
for root, dirs, files in os.walk("../../../../data/benchmark-cluster/explodingLiquid/"):
    for name in dirs:
        directories.append(os.path.join(root, name))


for directory in directories:
    files = os.listdir(directory)

    for file in files:
        # skip folders
        if ".csv" not in file:
            continue

        file_type = file.split("_")[1]

        print(f"Processing {file}")

        tuning_algorithm = directory.split("/")[-1]
        thread = directory.split("/")[-2]
        scenario = directory.split("/")[-3]

        with open(os.path.join(directory, file)) as f:
            print(directory, file)
            content = f.read()
            df_tuners = pd.read_csv(StringIO(content))

        if not scenario in data:
            data[scenario] = {}

        if not thread in data[scenario]:
            data[scenario][thread] = {}

        if not tuning_algorithm in data[scenario][thread]:
            data[scenario][thread][tuning_algorithm] = {}

        data[scenario][thread][tuning_algorithm][file_type] = df_tuners
# Out:
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-43-56.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianClusterSearch AutoPas_tuningResults_Rank0_2024-06-14_15-43-56.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-43-56.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianClusterSearch AutoPas_tuningData_Rank0_2024-06-14_15-43-56.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-56.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianClusterSearch AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-56.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-35.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Individual] AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-35.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_18-04-35.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Individual] AutoPas_tuningResults_Rank0_2024-06-15_18-04-35.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_18-04-35.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Individual] AutoPas_tuningData_Rank0_2024-06-15_18-04-35.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Suitability] AutoPas_tuningResults_Rank0_2024-06-14_15-44-27.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Suitability] AutoPas_tuningData_Rank0_2024-06-14_15-44-27.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FuzzyTuning [Suitability] AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-27.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianSearch AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-00.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-45-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianSearch AutoPas_tuningResults_Rank0_2024-06-14_15-45-00.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-45-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/BayesianSearch AutoPas_tuningData_Rank0_2024-06-14_15-45-00.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-26.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/PredictiveTuning AutoPas_tuningData_Rank0_2024-06-14_15-44-26.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-26.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/PredictiveTuning AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-26.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-26.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/PredictiveTuning AutoPas_tuningResults_Rank0_2024-06-14_15-44-26.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-45-11.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/RuleBasedTuning AutoPas_tuningData_Rank0_2024-06-14_15-45-11.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-11.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/RuleBasedTuning AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-11.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-45-11.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/RuleBasedTuning AutoPas_tuningResults_Rank0_2024-06-14_15-45-11.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_18-05-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FullSearch AutoPas_tuningData_Rank0_2024-06-15_18-05-42.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_18-05-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FullSearch AutoPas_tuningResults_Rank0_2024-06-15_18-05-42.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_18-05-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/12/FullSearch AutoPas_iterationPerformance_Rank0_2024-06-15_18-05-42.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-43-39.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianClusterSearch AutoPas_tuningData_Rank0_2024-06-14_15-43-39.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-43-39.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianClusterSearch AutoPas_tuningResults_Rank0_2024-06-14_15-43-39.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-39.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianClusterSearch AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-39.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Individual] AutoPas_tuningData_Rank0_2024-06-14_15-44-30.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Individual] AutoPas_tuningResults_Rank0_2024-06-14_15-44-30.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Individual] AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-30.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-08.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Suitability] AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-08.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-08.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Suitability] AutoPas_tuningData_Rank0_2024-06-14_15-44-08.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-08.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FuzzyTuning [Suitability] AutoPas_tuningResults_Rank0_2024-06-14_15-44-08.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-45-24.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianSearch AutoPas_tuningData_Rank0_2024-06-14_15-45-24.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-24.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianSearch AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-24.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-45-24.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/BayesianSearch AutoPas_tuningResults_Rank0_2024-06-14_15-45-24.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-45-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/PredictiveTuning AutoPas_tuningData_Rank0_2024-06-14_15-45-18.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-45-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/PredictiveTuning AutoPas_tuningResults_Rank0_2024-06-14_15-45-18.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/PredictiveTuning AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-18.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-45-23.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/RuleBasedTuning AutoPas_tuningData_Rank0_2024-06-14_15-45-23.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-45-23.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/RuleBasedTuning AutoPas_tuningResults_Rank0_2024-06-14_15-45-23.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-23.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/RuleBasedTuning AutoPas_iterationPerformance_Rank0_2024-06-14_15-45-23.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_18-04-19.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FullSearch AutoPas_tuningResults_Rank0_2024-06-15_18-04-19.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-19.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FullSearch AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-19.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_18-04-19.csv
# ../../../../data/benchmark-cluster/explodingLiquid/28/FullSearch AutoPas_tuningData_Rank0_2024-06-15_18-04-19.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_22-02-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianClusterSearch AutoPas_iterationPerformance_Rank0_2024-06-15_22-02-27.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_22-02-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianClusterSearch AutoPas_tuningResults_Rank0_2024-06-15_22-02-27.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_22-02-27.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianClusterSearch AutoPas_tuningData_Rank0_2024-06-15_22-02-27.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Individual] AutoPas_tuningResults_Rank0_2024-06-14_15-44-00.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Individual] AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-00.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-00.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Individual] AutoPas_tuningData_Rank0_2024-06-14_15-44-00.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-29.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Suitability] AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-29.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-43-29.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Suitability] AutoPas_tuningResults_Rank0_2024-06-14_15-43-29.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-43-29.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FuzzyTuning [Suitability] AutoPas_tuningData_Rank0_2024-06-14_15-43-29.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianSearch AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-18.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianSearch AutoPas_tuningResults_Rank0_2024-06-14_15-44-18.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-18.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/BayesianSearch AutoPas_tuningData_Rank0_2024-06-14_15-44-18.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_22-58-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/PredictiveTuning AutoPas_tuningResults_Rank0_2024-06-15_22-58-30.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_22-58-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/PredictiveTuning AutoPas_tuningData_Rank0_2024-06-15_22-58-30.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_22-58-30.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/PredictiveTuning AutoPas_iterationPerformance_Rank0_2024-06-15_22-58-30.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_18-04-44.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/RuleBasedTuning AutoPas_tuningData_Rank0_2024-06-15_18-04-44.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-44.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/RuleBasedTuning AutoPas_iterationPerformance_Rank0_2024-06-15_18-04-44.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_18-04-44.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/RuleBasedTuning AutoPas_tuningResults_Rank0_2024-06-15_18-04-44.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_23-20-45.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FullSearch AutoPas_tuningData_Rank0_2024-06-15_23-20-45.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_23-20-45.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FullSearch AutoPas_tuningResults_Rank0_2024-06-15_23-20-45.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_23-20-45.csv
# ../../../../data/benchmark-cluster/explodingLiquid/24/FullSearch AutoPas_iterationPerformance_Rank0_2024-06-15_23-20-45.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_14-44-15.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianClusterSearch AutoPas_tuningData_Rank0_2024-06-14_14-44-15.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_14-44-15.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianClusterSearch AutoPas_iterationPerformance_Rank0_2024-06-14_14-44-15.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_14-44-15.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianClusterSearch AutoPas_tuningResults_Rank0_2024-06-14_14-44-15.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-16.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Individual] AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-16.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-16.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Individual] AutoPas_tuningResults_Rank0_2024-06-14_15-44-16.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-16.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Individual] AutoPas_tuningData_Rank0_2024-06-14_15-44-16.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-43-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Suitability] AutoPas_tuningResults_Rank0_2024-06-14_15-43-42.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Suitability] AutoPas_iterationPerformance_Rank0_2024-06-14_15-43-42.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-43-42.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FuzzyTuning [Suitability] AutoPas_tuningData_Rank0_2024-06-14_15-43-42.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_14-42-53.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianSearch AutoPas_tuningResults_Rank0_2024-06-14_14-42-53.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_14-42-53.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianSearch AutoPas_tuningData_Rank0_2024-06-14_14-42-53.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_14-42-53.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/BayesianSearch AutoPas_iterationPerformance_Rank0_2024-06-14_14-42-53.csv
# Processing AutoPas_tuningData_Rank0_2024-06-14_15-44-32.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/PredictiveTuning AutoPas_tuningData_Rank0_2024-06-14_15-44-32.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-32.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/PredictiveTuning AutoPas_iterationPerformance_Rank0_2024-06-14_15-44-32.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-14_15-44-32.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/PredictiveTuning AutoPas_tuningResults_Rank0_2024-06-14_15-44-32.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_22-59-12.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/RuleBasedTuning AutoPas_iterationPerformance_Rank0_2024-06-15_22-59-12.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_22-59-12.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/RuleBasedTuning AutoPas_tuningData_Rank0_2024-06-15_22-59-12.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_22-59-12.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/RuleBasedTuning AutoPas_tuningResults_Rank0_2024-06-15_22-59-12.csv
# Processing AutoPas_iterationPerformance_Rank0_2024-06-15_22-58-05.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FullSearch AutoPas_iterationPerformance_Rank0_2024-06-15_22-58-05.csv
# Processing AutoPas_tuningData_Rank0_2024-06-15_22-58-05.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FullSearch AutoPas_tuningData_Rank0_2024-06-15_22-58-05.csv
# Processing AutoPas_tuningResults_Rank0_2024-06-15_22-58-05.csv
# ../../../../data/benchmark-cluster/explodingLiquid/1/FullSearch AutoPas_tuningResults_Rank0_2024-06-15_22-58-05.csv

# %% [markdown]
# # Make Line Plot of Smoothed Value over Iterations

# %% [markdown]
# # Make bar plots about total time

# %%
import numpy as np
# TODO FIX THIS. THE ITERATION IS NOT CORRECTLY ALIGNED

for scenario, s_data in data.items():
    print(scenario)

    for thread, thdata in s_data.items():
        print(thread)
        df_fullsearch = pd.DataFrame()
        df_tuners = pd.DataFrame()

        fig, ax = plt.subplots(1, 1, figsize=(28, 5))

        # sort by mean time spent calculating forces
        for tuning_algorithm, logs in thdata.items():
            print(tuning_algorithm)

            tuning_results = logs["iterationPerformance"]

            iteration = tuning_results["Iteration"]
            container = tuning_results["Container"]
            datalayout = tuning_results["Data Layout"]
            traversal = tuning_results["Traversal"]
            newton3 = tuning_results["Newton 3"]

            combined = []
            for (i, iter) in iteration.items():

                comb = " ".join(
                    [str(container.iloc[i]), str(datalayout.iloc[i]), str(traversal.iloc[i]), str(newton3.iloc[i])])
                combined.append(comb)

            total_config = pd.DataFrame(
                combined, columns=[tuning_algorithm])

            if "FullSearch" in tuning_algorithm:
                df_fullsearch = pd.concat(
                    [df_fullsearch, total_config], axis=1)
            else:
                df_tuners = pd.concat([df_tuners, total_config], axis=1)

        df = pd.concat([df_fullsearch, df_tuners], axis=1)

        # find nan values
        # replace nan values with "None"
        df = df.fillna("zzzzNone")

        value_to_int = {value: i for i, value in enumerate(
            sorted(pd.unique(df.values.ravel())))}
        value_to_int["zzzzNone"] = -1

        n = len(value_to_int)
        cmap = sns.color_palette("viridis", n)

        # color zzzzNone with white
        cmap[value_to_int["zzzzNone"]] = (1, 1, 1, 1)

        sns.heatmap(df.replace(value_to_int).T, cmap=cmap, ax=ax)

        

        colorbar = ax.collections[0].colorbar
        r = colorbar.vmax - colorbar.vmin

        # only show every k tick
        k = 5

        colorbar.set_ticks(
            [colorbar.vmin + r / (n-1) * i for i in range(0, n, k)])

        colorbar.set_ticklabels(
            [list(value_to_int.keys())[i] for i in range(0, n, k)])

        # legend below the heatmap


        ax.set_title(
            f"Applied Configurations during simulation of {scenario} with {thread} threads")
        ax.set_xlabel("Tuning Phase")
        ax.set_ylabel("Tuning Algorithm")

        # change x ticks to 2000 steps

        # set y label positon to the top left corner

        ax.spines['top'].set_visible(True)
        ax.spines['right'].set_visible(True)
        ax.spines['bottom'].set_visible(True)
        ax.spines['left'].set_visible(True)

        # set rotation of y labels
        # move y ticks a bit to the left

        # draw horizontal lines
        for i in range(1, len(df.index)):
            ax.axhline(i, color="black", lw=2)

        plt.show()


        plt.savefig(f"colorbar_{scenario}_{thread}.png", dpi=300)
     


        # fig.savefig(f"heatmap_{scenario}_{thread}.png", dpi=300)


    break
# Out:
# explodingLiquid
# 12
# BayesianClusterSearch
# FuzzyTuning [Individual]
# FuzzyTuning [Suitability]
# BayesianSearch
# PredictiveTuning
# RuleBasedTuning
# FullSearch
# /tmp/ipykernel_183238/2306529951.py:58: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sns.heatmap(df.replace(value_to_int).T, cmap=cmap, ax=ax)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 28
# BayesianClusterSearch
# FuzzyTuning [Individual]
# FuzzyTuning [Suitability]
# BayesianSearch
# PredictiveTuning
# RuleBasedTuning
# FullSearch
# /tmp/ipykernel_183238/2306529951.py:58: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sns.heatmap(df.replace(value_to_int).T, cmap=cmap, ax=ax)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 24
# BayesianClusterSearch
# FuzzyTuning [Individual]
# FuzzyTuning [Suitability]
# BayesianSearch
# PredictiveTuning
# RuleBasedTuning
# FullSearch
# /tmp/ipykernel_183238/2306529951.py:58: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sns.heatmap(df.replace(value_to_int).T, cmap=cmap, ax=ax)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1
# BayesianClusterSearch
# FuzzyTuning [Individual]
# FuzzyTuning [Suitability]
# BayesianSearch
# PredictiveTuning
# RuleBasedTuning
# FullSearch
# /tmp/ipykernel_183238/2306529951.py:58: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sns.heatmap(df.replace(value_to_int).T, cmap=cmap, ax=ax)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
