# %%
import pandas as pd
import sys

sys.path.insert(1, '../')

from rule_benchmark import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
FOLDERS = ["approach1", "approach2"]

# %%
train = pd.read_pickle("train.pkl")
test = pd.read_pickle("test.pkl")

# %%
# The K parameter selects how many defuzzified predictions are used in order of decreasing confidence
#pick random 1000 elements

X_train=train.sample(n=100)
X_test=test.sample(n=100)


fiss, algo_ranking = benchmark_rules("approach1/", X_train, X_test, K=1, n=600, suitability=True,method="cog")
fiss, algo_ranking = benchmark_rules("approach2/", X_train, X_test, K=1, n=600, suitability=True,method="cog")
# Out:
# Number of rules:  487
# Number of input variables:  6
# Number of output variables:  50
#
# approach1/:
#
# Suitability LinkedCells_AoS_lc_c01_disabled:
#   0%|          | 0/100 [00:00<?, ?it/s]/home/manuel/Documents/AutoPas-FuzzyTuning-Bachelor-Thesis/data-analysis/../demo/fuzzy-test/python/fuzzy_system.py:409: RuntimeWarning: overflow encountered in exp
#   def function(x): return 1 / (1 + np.exp(-width * (x - center)))
# 100%|██████████| 100/100 [00:07<00:00, 13.10it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.71it/s]
# Train: 0.18022462896509125
# Test: 0.17546266010509243
#
# Suitability LinkedCells_AoS_lc_c04_disabled:
# 100%|██████████| 100/100 [00:17<00:00,  5.65it/s]
# 100%|██████████| 100/100 [00:29<00:00,  3.39it/s]
# Train: 0.17140821740007517
# Test: 0.16642936383357082
#
# Suitability LinkedCells_AoS_lc_c04_enabled:
# 100%|██████████| 100/100 [00:07<00:00, 14.08it/s]
# 100%|██████████| 100/100 [00:09<00:00, 11.08it/s]
# Train: 0.11942349346480852
# Test: 0.14264609343069568
#
# Suitability LinkedCells_AoS_lc_c08_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.53it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.93it/s]
# Train: 0.1716411001868094
# Test: 0.16505632641191045
#
# Suitability LinkedCells_AoS_lc_c08_enabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.38it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.43it/s]
# Train: 0.11736330019776015
# Test: 0.13440131066891303
#
# Suitability LinkedCells_AoS_lc_c18_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.85it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.10it/s]
# Train: 0.1643197110493373
# Test: 0.1564121295343271
#
# Suitability LinkedCells_AoS_lc_c18_enabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.28it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.87it/s]
# Train: 0.1227913164768422
# Test: 0.13894350682161044
#
# Suitability LinkedCells_AoS_lc_sliced_disabled:
# 100%|██████████| 100/100 [00:04<00:00, 22.85it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.90it/s]
# Train: 0.16170866010551735
# Test: 0.15652345286797018
#
# Suitability LinkedCells_AoS_lc_sliced_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 14.37it/s]
# 100%|██████████| 100/100 [00:07<00:00, 14.26it/s]
# Train: 0.11662877626184555
# Test: 0.14236438992214676
#
# Suitability LinkedCells_AoS_lc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.23it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.00it/s]
# Train: 0.13098137111529584
# Test: 0.13295364737496398
#
# Suitability LinkedCells_AoS_lc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:08<00:00, 11.72it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.59it/s]
# Train: 0.1582855095675378
# Test: 0.15865360423829
#
# Suitability LinkedCells_AoS_lc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 14.57it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.35it/s]
# Train: 0.11651936096189393
# Test: 0.14190482896696294
#
# Suitability LinkedCells_SoA_lc_c01_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.60it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.82it/s]
# Train: 0.1225772750597253
# Test: 0.13469544609468118
#
# Suitability LinkedCells_SoA_lc_c04_disabled:
# 100%|██████████| 100/100 [00:11<00:00,  8.60it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.57it/s]
# Train: 0.11481245604583902
# Test: 0.13047275367671926
#
# Suitability LinkedCells_SoA_lc_c04_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.61it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.65it/s]
# Train: 0.15683370257322146
# Test: 0.15486204484946395
#
# Suitability LinkedCells_SoA_lc_c08_disabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.36it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.22it/s]
# Train: 0.1404199734126747
# Test: 0.1410030067587383
#
# Suitability LinkedCells_SoA_lc_c08_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.09it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.00it/s]
# Train: 0.14703054026450588
# Test: 0.15272204507759402
#
# Suitability LinkedCells_SoA_lc_c18_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.98it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.66it/s]
# Train: 0.14987898254874843
# Test: 0.1545659216819153
#
# Suitability LinkedCells_SoA_lc_c18_enabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.17it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.94it/s]
# Train: 0.130714721317474
# Test: 0.1426683259739628
#
# Suitability LinkedCells_SoA_lc_sliced_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.07it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.02it/s]
# Train: 0.1363849670017459
# Test: 0.15192818643451989
#
# Suitability LinkedCells_SoA_lc_sliced_enabled:
# 100%|██████████| 100/100 [00:11<00:00,  8.35it/s]
# 100%|██████████| 100/100 [00:14<00:00,  7.14it/s]
# Train: 0.204611112675835
# Test: 0.1979513270060154
#
# Suitability LinkedCells_SoA_lc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.57it/s]
# 100%|██████████| 100/100 [00:06<00:00, 15.08it/s]
# Train: 0.13347407143061418
# Test: 0.14459373149111168
#
# Suitability LinkedCells_SoA_lc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.43it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.37it/s]
# Train: 0.2270893301795149
# Test: 0.22911909855261506
#
# Suitability LinkedCells_SoA_lc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:14<00:00,  7.14it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.55it/s]
# Train: 0.12052890111675241
# Test: 0.13494491004470074
#
# Suitability LinkedCells_SoA_lc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:07<00:00, 12.91it/s]
# 100%|██████████| 100/100 [00:08<00:00, 12.43it/s]
# Train: 0.22661554997195363
# Test: 0.22933102294679483
#
# Suitability VerletClusterLists_AoS_vcl_c01_balanced_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.94it/s]
# 100%|██████████| 100/100 [00:06<00:00, 16.00it/s]
# Train: 0.2266395115599938
# Test: 0.21239582997767747
#
# Suitability VerletClusterLists_AoS_vcl_c06_disabled:
# 100%|██████████| 100/100 [00:08<00:00, 12.37it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.47it/s]
# Train: 0.24201356286645004
# Test: 0.23518316899133396
#
# Suitability VerletClusterLists_AoS_vcl_c06_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  7.75it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.77it/s]
# Train: 0.14033127763556563
# Test: 0.15537977317455512
#
# Suitability VerletClusterLists_AoS_vcl_cluster_iteration_disabled:
# 100%|██████████| 100/100 [00:08<00:00, 11.14it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.95it/s]
# Train: 0.21329029706983818
# Test: 0.1947294540647045
#
# Suitability VerletClusterLists_SoA_vcl_c01_balanced_disabled:
# 100%|██████████| 100/100 [00:17<00:00,  5.60it/s]
# 100%|██████████| 100/100 [00:19<00:00,  5.05it/s]
# Train: 0.12934019550797632
# Test: 0.16094696283234633
#
# Suitability VerletClusterLists_SoA_vcl_c06_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 11.07it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.02it/s]
# Train: 0.13612417396164128
# Test: 0.143202585179393
#
# Suitability VerletClusterLists_SoA_vcl_c06_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.27it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.65it/s]
# Train: 0.3627285471726808
# Test: 0.3886252705966396
#
# Suitability VerletClusterLists_SoA_vcl_cluster_iteration_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.62it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.38it/s]
# Train: 0.1337285998745331
# Test: 0.16088766851271305
#
# Suitability VerletListsCells_AoS_vlc_c01_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.27it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.44it/s]
# Train: 0.14744791330070078
# Test: 0.17495130312779897
#
# Suitability VerletListsCells_AoS_vlc_c18_disabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.13it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.00it/s]
# Train: 0.1358551436943179
# Test: 0.15127198253757462
#
# Suitability VerletListsCells_AoS_vlc_c18_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  7.75it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.92it/s]
# Train: 0.2945745124801225
# Test: 0.32369003736814006
#
# Suitability VerletListsCells_AoS_vlc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.18it/s]
# 100%|██████████| 100/100 [00:09<00:00, 11.04it/s]
# Train: 0.13040740475932913
# Test: 0.15140258728125974
#
# Suitability VerletListsCells_AoS_vlc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:04<00:00, 21.20it/s]
# 100%|██████████| 100/100 [00:04<00:00, 21.78it/s]
# Train: 0.3529539911134784
# Test: 0.3637935500192874
#
# Suitability VerletListsCells_AoS_vlc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:11<00:00,  9.04it/s]
# 100%|██████████| 100/100 [00:21<00:00,  4.65it/s]
# Train: 0.14038670911270545
# Test: 0.16110612117015108
#
# Suitability VerletListsCells_AoS_vlc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:23<00:00,  4.31it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.50it/s]
# Train: 0.3409835225022263
# Test: 0.37316914143561214
#
# Suitability VerletListsCells_SoA_vlc_c01_disabled:
# 100%|██████████| 100/100 [00:32<00:00,  3.10it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.30it/s]
# Train: 0.11850762103744794
# Test: 0.13577724334829944
#
# Suitability VerletListsCells_SoA_vlc_c18_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.46it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.57it/s]
# Train: 0.11592533857751672
# Test: 0.1388502493243423
#
# Suitability VerletListsCells_SoA_vlc_c18_enabled:
# 100%|██████████| 100/100 [00:16<00:00,  6.21it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.90it/s]
# Train: 0.16547483864340023
# Test: 0.18890287114279677
#
# Suitability VerletListsCells_SoA_vlc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.07it/s]
# 100%|██████████| 100/100 [00:12<00:00,  7.70it/s]
# Train: 0.13636344641363382
# Test: 0.12876353666200915
#
# Suitability VerletListsCells_SoA_vlc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.79it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.93it/s]
# Train: 0.16447565491475352
# Test: 0.19219104015512464
#
# Suitability VerletListsCells_SoA_vlc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.45it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.96it/s]
# Train: 0.11640739126289718
# Test: 0.13453739049873753
#
# Suitability VerletListsCells_SoA_vlc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.07it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.30it/s]
# Train: 0.19764586071952145
# Test: 0.22256276225309368
#
# Suitability VerletLists_AoS_vl_list_iteration_disabled:
# 100%|██████████| 100/100 [00:03<00:00, 26.90it/s]
# 100%|██████████| 100/100 [00:03<00:00, 30.27it/s]
# Train: 0.11947173538292027
# Test: 0.13643044110353084
#
# Suitability VerletLists_SoA_vl_list_iteration_disabled:
# 100%|██████████| 100/100 [00:08<00:00, 11.62it/s]
# 100%|██████████| 100/100 [00:08<00:00, 12.18it/s]
# Train: 0.13621763237764678
# Test: 0.15952998561897086
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Number of rules:  487
# Number of input variables:  6
# Number of output variables:  50
#
# approach2/:
#
# Suitability LinkedCells_AoS_lc_c01_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.48it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.93it/s]
# Train: 0.176907972003383
# Test: 0.1688725808090832
#
# Suitability LinkedCells_AoS_lc_c04_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.97it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.36it/s]
# Train: 0.17209977261823928
# Test: 0.16430016373046682
#
# Suitability LinkedCells_AoS_lc_c04_enabled:
# 100%|██████████| 100/100 [00:04<00:00, 21.32it/s]
# 100%|██████████| 100/100 [00:04<00:00, 22.93it/s]
# Train: 0.11300954913604286
# Test: 0.133721235746737
#
# Suitability LinkedCells_AoS_lc_c08_disabled:
# 100%|██████████| 100/100 [00:03<00:00, 26.80it/s]
# 100%|██████████| 100/100 [00:03<00:00, 28.24it/s]
# Train: 0.16357736039458232
# Test: 0.15637987918155882
#
# Suitability LinkedCells_AoS_lc_c08_enabled:
# 100%|██████████| 100/100 [00:14<00:00,  6.69it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.34it/s]
# Train: 0.1092623787565902
# Test: 0.1296121539189202
#
# Suitability LinkedCells_AoS_lc_c18_disabled:
# 100%|██████████| 100/100 [00:07<00:00, 14.00it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.95it/s]
# Train: 0.1575569736385462
# Test: 0.15196090251626285
#
# Suitability LinkedCells_AoS_lc_c18_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 14.77it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.65it/s]
# Train: 0.11804037420426823
# Test: 0.13120743103424906
#
# Suitability LinkedCells_AoS_lc_sliced_disabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.98it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.62it/s]
# Train: 0.15422094719411486
# Test: 0.14845293334855716
#
# Suitability LinkedCells_AoS_lc_sliced_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.38it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.25it/s]
# Train: 0.11213573076256386
# Test: 0.1332605482840045
#
# Suitability LinkedCells_AoS_lc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.65it/s]
# 100%|██████████| 100/100 [00:06<00:00, 16.37it/s]
# Train: 0.11780378756932791
# Test: 0.12903141766111564
#
# Suitability LinkedCells_AoS_lc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.23it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.89it/s]
# Train: 0.15947278995805353
# Test: 0.1547848476579227
#
# Suitability LinkedCells_AoS_lc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.59it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.13it/s]
# Train: 0.11245964077776957
# Test: 0.13303767127174257
#
# Suitability LinkedCells_SoA_lc_c01_disabled:
# 100%|██████████| 100/100 [00:14<00:00,  7.09it/s]
# 100%|██████████| 100/100 [00:14<00:00,  7.00it/s]
# Train: 0.11509046422455645
# Test: 0.12967952467350888
#
# Suitability LinkedCells_SoA_lc_c04_disabled:
# 100%|██████████| 100/100 [00:14<00:00,  6.93it/s]
# 100%|██████████| 100/100 [00:14<00:00,  7.14it/s]
# Train: 0.11184723335347428
# Test: 0.1341104704779405
#
# Suitability LinkedCells_SoA_lc_c04_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  7.73it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.14it/s]
# Train: 0.18567271392799306
# Test: 0.1931328103614076
#
# Suitability LinkedCells_SoA_lc_c08_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  7.91it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.66it/s]
# Train: 0.11854289587572006
# Test: 0.13135952534820608
#
# Suitability LinkedCells_SoA_lc_c08_enabled:
# 100%|██████████| 100/100 [00:19<00:00,  5.24it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.26it/s]
# Train: 0.17911464503925864
# Test: 0.19099911095916336
#
# Suitability LinkedCells_SoA_lc_c18_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.27it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.90it/s]
# Train: 0.12787805593881182
# Test: 0.13786721980529001
#
# Suitability LinkedCells_SoA_lc_c18_enabled:
# 100%|██████████| 100/100 [00:07<00:00, 13.47it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.83it/s]
# Train: 0.14154817201502762
# Test: 0.1573804185948437
#
# Suitability LinkedCells_SoA_lc_sliced_disabled:
# 100%|██████████| 100/100 [00:16<00:00,  6.07it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.36it/s]
# Train: 0.12718455007150212
# Test: 0.1412144543816641
#
# Suitability LinkedCells_SoA_lc_sliced_enabled:
# 100%|██████████| 100/100 [00:08<00:00, 12.01it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.30it/s]
# Train: 0.2207303305978408
# Test: 0.22446826051824612
#
# Suitability LinkedCells_SoA_lc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.26it/s]
# 100%|██████████| 100/100 [00:07<00:00, 14.05it/s]
# Train: 0.12814703239404182
# Test: 0.14741958415267947
#
# Suitability LinkedCells_SoA_lc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:11<00:00,  8.39it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.44it/s]
# Train: 0.19337382438305958
# Test: 0.20302035292651016
#
# Suitability LinkedCells_SoA_lc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:16<00:00,  6.16it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.27it/s]
# Train: 0.11685113836885247
# Test: 0.13199602807189806
#
# Suitability LinkedCells_SoA_lc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:08<00:00, 11.56it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.89it/s]
# Train: 0.23726648773638623
# Test: 0.24507899037743608
#
# Suitability VerletClusterLists_AoS_vcl_c01_balanced_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 15.08it/s]
# 100%|██████████| 100/100 [00:06<00:00, 15.91it/s]
# Train: 0.22058306080194126
# Test: 0.210495510170666
#
# Suitability VerletClusterLists_AoS_vcl_c06_disabled:
# 100%|██████████| 100/100 [00:06<00:00, 14.69it/s]
# 100%|██████████| 100/100 [00:06<00:00, 15.92it/s]
# Train: 0.22000910983446176
# Test: 0.21097013064767933
#
# Suitability VerletClusterLists_AoS_vcl_c06_enabled:
# 100%|██████████| 100/100 [00:11<00:00,  8.91it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.53it/s]
# Train: 0.13320798633893777
# Test: 0.13738517899998412
#
# Suitability VerletClusterLists_AoS_vcl_cluster_iteration_disabled:
# 100%|██████████| 100/100 [00:07<00:00, 14.18it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.19it/s]
# Train: 0.2118939058159518
# Test: 0.1947825451149659
#
# Suitability VerletClusterLists_SoA_vcl_c01_balanced_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.03it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.34it/s]
# Train: 0.11999070814026283
# Test: 0.13388950719271103
#
# Suitability VerletClusterLists_SoA_vcl_c06_disabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.28it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.28it/s]
# Train: 0.13060550619983716
# Test: 0.13572306614720475
#
# Suitability VerletClusterLists_SoA_vcl_c06_enabled:
# 100%|██████████| 100/100 [00:06<00:00, 14.43it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.62it/s]
# Train: 0.26275010173443863
# Test: 0.2863053851750237
#
# Suitability VerletClusterLists_SoA_vcl_cluster_iteration_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.68it/s]
# 100%|██████████| 100/100 [00:09<00:00, 11.09it/s]
# Train: 0.15036389067989592
# Test: 0.17341591682055943
#
# Suitability VerletListsCells_AoS_vlc_c01_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.19it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.68it/s]
# Train: 0.13432631544630003
# Test: 0.16166182066623752
#
# Suitability VerletListsCells_AoS_vlc_c18_disabled:
# 100%|██████████| 100/100 [00:05<00:00, 17.09it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.35it/s]
# Train: 0.12526165036766937
# Test: 0.1397714458561147
#
# Suitability VerletListsCells_AoS_vlc_c18_enabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.28it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.64it/s]
# Train: 0.26672423679366664
# Test: 0.2945737808347487
#
# Suitability VerletListsCells_AoS_vlc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.70it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.89it/s]
# Train: 0.126875717083468
# Test: 0.1476470325941917
#
# Suitability VerletListsCells_AoS_vlc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:04<00:00, 21.19it/s]
# 100%|██████████| 100/100 [00:04<00:00, 22.54it/s]
# Train: 0.325833911342128
# Test: 0.3493865324270227
#
# Suitability VerletListsCells_AoS_vlc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:12<00:00,  8.08it/s]
# 100%|██████████| 100/100 [00:12<00:00,  7.82it/s]
# Train: 0.13470357282287806
# Test: 0.15464606253178728
#
# Suitability VerletListsCells_AoS_vlc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.89it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.27it/s]
# Train: 0.2965121036607348
# Test: 0.32603496452366526
#
# Suitability VerletListsCells_SoA_vlc_c01_disabled:
# 100%|██████████| 100/100 [00:13<00:00,  7.25it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.39it/s]
# Train: 0.12099682425092917
# Test: 0.1431076244993788
#
# Suitability VerletListsCells_SoA_vlc_c18_disabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.20it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.64it/s]
# Train: 0.111890904002421
# Test: 0.1316883324415226
#
# Suitability VerletListsCells_SoA_vlc_c18_enabled:
# 100%|██████████| 100/100 [00:09<00:00, 10.51it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.31it/s]
# Train: 0.16801246586108778
# Test: 0.19261137569479833
#
# Suitability VerletListsCells_SoA_vlc_sliced_balanced_disabled:
# 100%|██████████| 100/100 [00:11<00:00,  8.82it/s]
# 100%|██████████| 100/100 [00:12<00:00,  7.75it/s]
# Train: 0.12964218377083997
# Test: 0.13044529208059746
#
# Suitability VerletListsCells_SoA_vlc_sliced_balanced_enabled:
# 100%|██████████| 100/100 [00:08<00:00, 11.28it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.98it/s]
# Train: 0.21876866234178183
# Test: 0.26262375592501197
#
# Suitability VerletListsCells_SoA_vlc_sliced_c02_disabled:
# 100%|██████████| 100/100 [00:05<00:00, 18.41it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.05it/s]
# Train: 0.11481780455936962
# Test: 0.1278185542774333
#
# Suitability VerletListsCells_SoA_vlc_sliced_c02_enabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.13it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.60it/s]
# Train: 0.20442487420580477
# Test: 0.21794915098052706
#
# Suitability VerletLists_AoS_vl_list_iteration_disabled:
# 100%|██████████| 100/100 [00:04<00:00, 24.20it/s]
# 100%|██████████| 100/100 [00:04<00:00, 24.94it/s]
# Train: 0.11459930456936845
# Test: 0.12997131062111925
#
# Suitability VerletLists_SoA_vl_list_iteration_disabled:
# 100%|██████████| 100/100 [00:10<00:00,  9.92it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.45it/s]
# Train: 0.13141463188152167
# Test: 0.15122330944373963
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = {"maxDensity": 0.1, "maxParticlesPerCell": 2,  "homogeneity": 0.1,
        "particlesPerCellStdDev": 0.1, "avgParticlesPerCell": 0.1, "threadCount": 10}


union = fiss["Suitability LinkedCells_SoA_lc_c04_enabled"].applyRules(data)

fig, ax = plt.subplots()
union.plot(ax=ax, n=1000, defuzzifiationMethod="cog")

print("Union: ", union)

prediction = fiss["Suitability LinkedCells_SoA_lc_c04_enabled"].predictClosest(
    data, algo_ranking["Suitability LinkedCells_SoA_lc_c04_enabled"], n=600,method="cog")[1]

print("Prediction: ", prediction)
# Out:
# Union:  "("("("("("("("("("("("("(Suitability LinkedCells_SoA_lc_c04_enabled is "excellent": Gaussian(0.875, 0.017857142857142856))↑0.59" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "medium": Gaussian(0.5, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "medium": Gaussian(0.5, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "good": Gaussian(0.75, 0.017857142857142856))↑0.41")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "ok": Gaussian(0.625, 0.017857142857142856))↑0.01")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "medium": Gaussian(0.5, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "bad": Gaussian(0.375, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "ok": Gaussian(0.625, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "good": Gaussian(0.75, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "bad": Gaussian(0.375, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "good": Gaussian(0.75, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "bad": Gaussian(0.375, 0.017857142857142856))↑0.00")" or "(Suitability LinkedCells_SoA_lc_c04_enabled is "ok": Gaussian(0.625, 0.017857142857142856))↑0.00")"
# Prediction:  excellent
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np

X = np.linspace(0, 1.5, 20)
Y = np.linspace(0, 4, 20)

# %%
Z_cog = np.array(
    [[fiss["Suitability LinkedCells_SoA_lc_c04_enabled"].predict({"homogeneity": x, "avgParticlesPerCell": y,"threadCount":16,"maxDensity":1.4}, method="cog") for x in X] for y in Y])

# %%
import matplotlib as mpl

def plot(X, Y, Z):
    fig, axs = plt.subplots(1)
    axs.set_xlabel("homogeneity")
    axs.set_ylabel("avgParticlesPerCell")

    # xlabes only integers
    axs.set_xticks(np.arange(0, 5.5, 0.5))
    axs.set_yticks(np.arange(0, 4.5, 0.5))

    # label positions at end of axis
    axs.xaxis.set_label_coords(0.95, -0.1)
    axs.yaxis.set_label_coords(-0.1, 0.95)

    # y label rotated
    axs.yaxis.label.set_rotation(0)

    my_cmap = mpl.colors.LinearSegmentedColormap.from_list(
        "", ["blue", "red", "green"])

    countour = axs.contourf(X, Y, Z, levels=100,
                            cmap=my_cmap, extend='both')

    cbar = fig.colorbar(countour, ax=axs)
    cbar.set_label("Suitability")

    #title
    axs.set_title(f"Suitability for LinkedCells_SoA_lc_c04_enabled")

    return fig



plot(X, Y, Z_cog);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
